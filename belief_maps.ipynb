# %%
combined_belief_map = {
    # Nihilism files (already categorized)
    'Nietzsche_antichrist.txt': 'Negative',
    'Nietzsche_The Will to Power.txt': 'Negative',
    'Nietzsche_The-Birth-of-Tragedy.txt': 'Negative',
    'Cioran_heights.txt': 'Negative',
    'Cioran_short.txt': 'Negative',
    'Cioran_Trouble.txt': 'Negative',
    'Sartre_being-and-nothingness.txt': 'Negative',
    'Sartre_eih.txt': 'Negative',
    'Sartre_Nausea.txt': 'Negative',
    'Schopenhauer_On the Sufferings of the World - Arthur Schopenhauer - PDF.txt': 'Negative',
    'Schopenhauer_vanity.txt': 'Negative',
    'Schopenhauer_world-as-.txt': 'Negative',
    'Camus_Myth of Sisyphus.txt': 'Positive',
    'Camus_ThePlague-Camus.txt': 'Positive',
    'Camus_The_Stranger_-_Albert_Camus.txt': 'Positive',
    'Marcel_being_and_having.txt': 'Positive',
    'Marcel_mystery-of-being.txt': 'Positive',
    'Marcel_viator.txt': 'Positive',
    'Kierkegaard_Fear and Trembling book Kierkegaard.txt': 'Positive',
    'Kierkegaard_Fragments.txt': 'Positive',
    'Kierkegaard_The Concept of Anxiety.txt': 'Positive',
    'Buber_Between_Man_and_Man.txt': 'Positive',
    'Buber_Way-of_man.txt': 'Positive',

    # Romanticism files
    'Burke_Reflections.txt': 'Negative',
    'Burke_VindicationNaturalSociety.txt': 'Negative',
    'Coleridge_kubla.txt': 'Positive',
    'Coleridge_The-Rime-of-the-Ancient-Mariner.txt': 'Positive',
    'Goethe_Apprecitce.txt': 'Positive',
    'Goethe_faust.txt': 'Positive',
    'Goethe_Sorrows.txt': 'Positive',
    'Hegel_right.txt': 'Negative',
    'Hegel_The Phenomenology of Spirit .txt': 'Negative',
    'Hegel_The_Science_of_Logic.txt': 'Negative',
    'Hume_enquiry.txt': 'Negative',
    'Hume_Natural_Religion.txt': 'Negative',
    'Hume_Treatise_Human_Nature.txt': 'Negative',
    'Kant_Groundwork.txt': 'Negative',
    'Kant_Immanuel_Judgement.txt': 'Negative',
    'Kant_Pure_reason.txt': 'Negative',
    'Rousseau_Education.txt': 'Positive',
    'Rousseau_Social_Contract.txt': 'Positive',
    'Rousseau_The_Confessions-Jean-Jacques_Rousseau.txt': 'Positive',
    'Wordsworth_Ballads.txt': 'Positive',
    'Wordsworth_Prelude.txt': 'Positive',
    'Wordsworth_tintern.txt': 'Positive',

    # Stoicism files
    'Camus_Myth of Sisyphus.txt': 'Negative',
    'Camus_ThePlague-Camus.txt': 'Negative',
    'Camus_The_Stranger_-_Albert_Camus.txt': 'Negative',
    'Foucault_disciplineandpunish-min.txt': 'Negative',
    'Foucault_Michel_Discipline_and_Punish_The_Birth_of_the_Prison_1977_1995.txt': 'Negative',
    'Foucault_Michel_The_History_of_Sexuality_1_An_Introduction.txt': 'Negative',
    'Hadot_philosophy-as-a-way-of-life-spiritual-exercises-from-socrates-to-foucault-1.txt': 'Positive',
    'Hadot_the-inner-citadel-the-meditations-of-marcus-aurelius-pdfdrive-.txt': 'Positive',
    'Hadot_The_Present_Alone_is_Our_Happiness_Co.txt': 'Positive',
    'Holiday_Ego_is_the_Enenmyz-lib.org_.txt': 'Positive',
    'Holiday_The_Daily_Stoic_366_Meditations_on_Wisdom,_Perseverance,_and_the.txt': 'Positive',
    'Holiday_The_Obstacle_In_The_Way.txt': 'Positive',
    'Irvine_why_we_want.txt': 'Positive',
    'Montaigne_essays.txt': 'Positive',
    'Nietzsche_The Will to Power.txt': 'Negative',
    'Nietzsche_The-Birth-of-Tragedy.txt': 'Negative',
    'Sartre_being-and-nothingness.txt': 'Negative',
    'Sartre_eih.txt': 'Negative',
    'Sartre_Nausea.txt': 'Negative'
}

# %%
filenames = [
    # Nihilism files
    'Nietzsche_antichrist.txt',
    'Nietzsche_The Will to Power.txt',
    'Nietzsche_The-Birth-of-Tragedy.txt',
    'Cioran_heights.txt',
    'Cioran_short.txt',
    'Cioran_Trouble.txt',
    'Sartre_being-and-nothingness.txt',
    'Sartre_eih.txt',
    'Sartre_Nausea.txt',
    'Schopenhauer_On the Sufferings of the World - Arthur Schopenhauer - PDF.txt',
    'Schopenhauer_vanity.txt',
    'Schopenhauer_world-as-.txt',
    'Camus_Myth of Sisyphus.txt',
    'Camus_ThePlague-Camus.txt',
    'Camus_The_Stranger_-_Albert_Camus.txt',
    'Marcel_being_and_having.txt',
    'Marcel_mystery-of-being.txt',
    'Marcel_viator.txt',
    'Kierkegaard_Fear and Trembling book Kierkegaard.txt',
    'Kierkegaard_Fragments.txt',
    'Kierkegaard_The Concept of Anxiety.txt',
    'Buber_Between_Man_and_Man.txt',
    'Buber_Way-of_man.txt',

    # Romanticism files
    'Burke_Reflections.txt',
    'Burke_VindicationNaturalSociety.txt',
    'Coleridge_kubla.txt',
    'Coleridge_The-Rime-of-the-Ancient-Mariner.txt',
    'Goethe_Apprecitce.txt',
    'Goethe_faust.txt',
    'Goethe_Sorrows.txt',
    'Hegel_right.txt',
    'Hegel_The Phenomenology of Spirit .txt',
    'Hegel_The_Science_of_Logic.txt',
    'Hume_enquiry.txt',
    'Hume_Natural_Religion.txt',
    'Hume_Treatise_Human_Nature.txt',
    'Kant_Groundwork.txt',
    'Kant_Immanuel_Judgement.txt',
    'Kant_Pure_reason.txt',
    'Rousseau_Education.txt',
    'Rousseau_Social_Contract.txt',
    'Rousseau_The_Confessions-Jean-Jacques_Rousseau.txt',
    'Wordsworth_Ballads.txt',
    'Wordsworth_Prelude.txt',
    'Wordsworth_tintern.txt',

    # Stoicism files
    'Camus_Myth of Sisyphus.txt',
    'Camus_ThePlague-Camus.txt',
    'Camus_The_Stranger_-_Albert_Camus.txt',
    'Foucault_disciplineandpunish-min.txt',
    'Foucault_Michel_Discipline_and_Punish_The_Birth_of_the_Prison_1977_1995.txt',
    'Foucault_Michel_The_History_of_Sexuality_1_An_Introduction.txt',
    'Hadot_philosophy-as-a-way-of-life-spiritual-exercises-from-socrates-to-foucault-1.txt',
    'Hadot_the-inner-citadel-the-meditations-of-marcus-aurelius-pdfdrive-.txt',
    'Hadot_The_Present_Alone_is_Our_Happiness_Co.txt',
    'Holiday_Ego_is_the_Enenmyz-lib.org_.txt',
    'Holiday_The_Daily_Stoic_366_Meditations_on_Wisdom,_Perseverance,_and_the.txt',
    'Holiday_The_Obstacle_In_The_Way.txt',
    'Irvine_why_we_want.txt',
    'Montaigne_essays.txt',
    'Nietzsche_The Will to Power.txt',
    'Nietzsche_The-Birth-of-Tragedy.txt',
    'Sartre_being-and-nothingness.txt',
    'Sartre_eih.txt',
    'Sartre_Nausea.txt'
]

# %%
with open('belief_maps.py', 'w') as f:
    f.write(f"combined_belief_map = {combined_belief_map}\n")
    f.write(f"filenames = {filenames}\n")
